# %%
import numpy as np
import pandas as pd
import os
import shap
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
import lime
import lime.lime_tabular
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, accuracy_score
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb
from sklearn.linear_model import Ridge
from sklearn.impute import SimpleImputer
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %%
linear = pd.read_csv('/home/peter/Documents/DSProject/FilteredDataFour.csv')

# %% [raw]
# linear.drop(columns=["State", "County"], inplace=True)

# %%
linear
# Out:
#           State    County  Date Local          NO2 Units   NO2 Mean  \
# 0       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 1       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 2       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 3       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 4       Arizona  Maricopa  2012-01-02  Parts per billion  17.208333
# ...         ...       ...         ...                ...        ...
# 394366  Wyoming   Laramie  2014-12-30  Parts per billion   7.579167
# 394367  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
# 394368  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
# 394369  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
# 394370  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
#
#         NO2 1st Max Value  NO2 1st Max Hour  NO2 AQI           O3 Units  \
# 0                    33.0                 0       31  Parts per million
# ...

# %%
linear
# Out:
#           State    County  Date Local          NO2 Units   NO2 Mean  \
# 0       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 1       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 2       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 3       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 4       Arizona  Maricopa  2012-01-02  Parts per billion  17.208333
# ...         ...       ...         ...                ...        ...
# 394366  Wyoming   Laramie  2014-12-30  Parts per billion   7.579167
# 394367  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
# 394368  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
# 394369  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
# 394370  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
#
#         NO2 1st Max Value  NO2 1st Max Hour  NO2 AQI           O3 Units  \
# 0                    33.0                 0       31  Parts per million
# ...

# %%
linear.drop(columns=["State", "County"], inplace=True)

# %%
linear
# Out:
#         Date Local          NO2 Units   NO2 Mean  NO2 1st Max Value  \
# 0       2012-01-01  Parts per billion  21.208333               33.0
# 1       2012-01-01  Parts per billion  21.208333               33.0
# 2       2012-01-01  Parts per billion  21.208333               33.0
# 3       2012-01-01  Parts per billion  21.208333               33.0
# 4       2012-01-02  Parts per billion  17.208333               38.0
# ...            ...                ...        ...                ...
# 394366  2014-12-30  Parts per billion   7.579167               29.5
# 394367  2014-12-31  Parts per billion   4.420833               12.6
# 394368  2014-12-31  Parts per billion   4.420833               12.6
# 394369  2014-12-31  Parts per billion   4.420833               12.6
# 394370  2014-12-31  Parts per billion   4.420833               12.6
#
#         NO2 1st Max Hour  NO2 AQI           O3 Units   O3 Mean  \
# 0                      0       31  Parts per million  0.015083
# ...

# %%
linear.drop(columns=["NO2 Units", "O3 Units"], inplace=True)

# %%
linear.drop(columns=["SO2 Units", "CO Units"], inplace=True)

# %%
linear
# Out:
#         Date Local   NO2 Mean  NO2 1st Max Value  NO2 1st Max Hour  NO2 AQI  \
# 0       2012-01-01  21.208333               33.0                 0       31
# 1       2012-01-01  21.208333               33.0                 0       31
# 2       2012-01-01  21.208333               33.0                 0       31
# 3       2012-01-01  21.208333               33.0                 0       31
# 4       2012-01-02  17.208333               38.0                22       36
# ...            ...        ...                ...               ...      ...
# 394366  2014-12-30   7.579167               29.5                20       27
# 394367  2014-12-31   4.420833               12.6                 0       11
# 394368  2014-12-31   4.420833               12.6                 0       11
# 394369  2014-12-31   4.420833               12.6                 0       11
# 394370  2014-12-31   4.420833               12.6                 0       11
#
# ...

# %%
linear['Date Local'] = pd.to_datetime(linear['Date Local'], utc=True)
linear.sort_values(by=['Date Local'], inplace=True, ascending=True)

# %%
swt_data = linear.groupby([linear['Date Local'].dt.date]).mean()

# %%
plt.figure(figsize=(30,10))
plt.plot(swt_data["NO2 AQI"][:1050])
plt.grid()
plt.show()
