# %%
import pandas as pd

# %%
test = pd.read_csv('/home/peter/Documents/DSProject/FilteredDataThree.csv')

# %%
test
# Out:
#           State    County  Date Local          NO2 Units   NO2 Mean  \
# 0       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 1       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 2       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 3       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 4       Arizona  Maricopa  2012-01-02  Parts per billion  17.208333
# ...         ...       ...         ...                ...        ...
# 394366  Wyoming   Laramie  2014-12-30  Parts per billion   7.579167
# 394367  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
# 394368  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
# 394369  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
# 394370  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
#
#         NO2 1st Max Value  NO2 1st Max Hour  NO2 AQI           O3 Units  \
# 0                    33.0                 0       31  Parts per million
# ...

# %%
col=test["SO2 AQI"]

# %%
maxVal=col.idxmax()

# %%
maxVal
# Out:
# 64016

# %%
maxVal=test.max()

# %%
maxVal
# Out:
# State                          Wyoming
# County                            York
# Date Local                  2014-12-31
# NO2 Units            Parts per billion
# NO2 Mean                       79.4783
# NO2 1st Max Value                156.9
# NO2 1st Max Hour                    23
# NO2 AQI                            111
# O3 Units             Parts per million
# O3 Mean                       0.083045
# O3 1st Max Value                 0.122
# O3 1st Max Hour                     23
# O3 AQI                             218
# SO2 Units            Parts per billion
# SO2 Mean                       34.1143
# SO2 1st Max Value                211.9
# SO2 1st Max Hour                    23
# SO2 AQI                            161
# CO Units             Parts per million
# CO Mean                        3.48571
# CO 1st Max Value                 12.46
# CO 1st Max Hour                     23
# CO AQI                              56
# dtype: object

# %%
test.tail(20)
# Out:
#           State   County  Date Local          NO2 Units  NO2 Mean  \
# 394351  Wyoming  Laramie  2014-12-19  Parts per billion  4.300000
# 394352  Wyoming  Laramie  2014-12-19  Parts per billion  4.300000
# 394353  Wyoming  Laramie  2014-12-19  Parts per billion  4.300000
# 394354  Wyoming  Laramie  2014-12-19  Parts per billion  4.300000
# 394355  Wyoming  Laramie  2014-12-20  Parts per billion  4.437500
# 394356  Wyoming  Laramie  2014-12-20  Parts per billion  4.437500
# 394357  Wyoming  Laramie  2014-12-20  Parts per billion  4.437500
# 394358  Wyoming  Laramie  2014-12-20  Parts per billion  4.437500
# 394359  Wyoming  Laramie  2014-12-29  Parts per billion  1.370833
# 394360  Wyoming  Laramie  2014-12-29  Parts per billion  1.370833
# 394361  Wyoming  Laramie  2014-12-29  Parts per billion  1.370833
# 394362  Wyoming  Laramie  2014-12-29  Parts per billion  1.370833
# 394363  Wyoming  Laramie  2014-12-30  Parts per billion  7.579167
# ...

# %%
max=test['SO2 AQI'].average()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-2b693df95a99> in <module>
# ----> 1 max=test['SO2 AQI'].average()
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'average'

# %%
max
# Out:
# 161.0

# %%
max=test.print("Wyoming")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-6fb8f5baba4b> in <module>
# ----> 1 max=test.print("Wyoming")
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'print'

# %%
Wyoming
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-433c71bd9548> in <module>
# ----> 1 print(max.loc[["Wyoming"]])
#
# AttributeError: 'float' object has no attribute 'loc'

# %%
test.loc["Wyoming","State"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Wyoming'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-30304ba8b526> in <module>
# ----> 1 test.loc["Wyoming","State"]
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
# ...

# %%
test
# Out:
#           State    County  Date Local          NO2 Units   NO2 Mean  \
# 0       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 1       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 2       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 3       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 4       Arizona  Maricopa  2012-01-02  Parts per billion  17.208333
# ...         ...       ...         ...                ...        ...
# 394366  Wyoming   Laramie  2014-12-30  Parts per billion   7.579167
# 394367  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
# 394368  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
# 394369  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
# 394370  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
#
#         NO2 1st Max Value  NO2 1st Max Hour  NO2 AQI           O3 Units  \
# 0                    33.0                 0       31  Parts per million
# ...

# %%
test=test.loc[2]

# %%
test
# Out:
# State                          Arizona
# County                        Maricopa
# Date Local                  2012-01-01
# NO2 Units            Parts per billion
# NO2 Mean                       21.2083
# NO2 1st Max Value                   33
# NO2 1st Max Hour                     0
# NO2 AQI                             31
# O3 Units             Parts per million
# O3 Mean                       0.015083
# O3 1st Max Value                 0.028
# O3 1st Max Hour                     11
# O3 AQI                              24
# SO2 Units            Parts per billion
# SO2 Mean                        1.4375
# SO2 1st Max Value                  4.6
# SO2 1st Max Hour                     2
# SO2 AQI                            NaN
# CO Units             Parts per million
# CO Mean                        1.18333
# CO 1st Max Value                   3.3
# CO 1st Max Hour                      0
# CO AQI                             NaN
# Name: 2, dtype: object

# %%
max
# Out:
# 161.0

# %%
test
# Out:
#           State    County  Date Local          NO2 Units   NO2 Mean  \
# 0       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 1       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 2       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 3       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 4       Arizona  Maricopa  2012-01-02  Parts per billion  17.208333
# ...         ...       ...         ...                ...        ...
# 394366  Wyoming   Laramie  2014-12-30  Parts per billion   7.579167
# 394367  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
# 394368  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
# 394369  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
# 394370  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
#
#         NO2 1st Max Value  NO2 1st Max Hour  NO2 AQI           O3 Units  \
# 0                    33.0                 0       31  Parts per million
# ...

# %%
# Out:
#           State   County  Date Local          NO2 Units  NO2 Mean  \
# 125326  Wyoming  Laramie  2012-01-01  Parts per billion  8.366667
# 125327  Wyoming  Laramie  2012-01-01  Parts per billion  8.366667
# 125328  Wyoming  Laramie  2012-01-01  Parts per billion  8.366667
# 125329  Wyoming  Laramie  2012-01-01  Parts per billion  8.366667
# 125330  Wyoming  Laramie  2012-01-02  Parts per billion  9.347826
# ...         ...      ...         ...                ...       ...
# 394366  Wyoming  Laramie  2014-12-30  Parts per billion  7.579167
# 394367  Wyoming  Laramie  2014-12-31  Parts per billion  4.420833
# 394368  Wyoming  Laramie  2014-12-31  Parts per billion  4.420833
# 394369  Wyoming  Laramie  2014-12-31  Parts per billion  4.420833
# 394370  Wyoming  Laramie  2014-12-31  Parts per billion  4.420833
#
#         NO2 1st Max Value  NO2 1st Max Hour  NO2 AQI           O3 Units  \
# 125326               19.3                 3       18  Parts per million
# ...

# %%
save = test

# %%
test.loc[test['County'] == 'York']
# Out:
#                State County  Date Local          NO2 Units   NO2 Mean  \
# 106326  Pennsylvania   York  2012-01-01  Parts per billion   9.500000
# 106327  Pennsylvania   York  2012-01-01  Parts per billion   9.500000
# 106328  Pennsylvania   York  2012-01-01  Parts per billion   9.500000
# 106329  Pennsylvania   York  2012-01-01  Parts per billion   9.500000
# 106330  Pennsylvania   York  2012-01-02  Parts per billion   6.166667
# ...              ...    ...         ...                ...        ...
# 375218  Pennsylvania   York  2014-12-30  Parts per billion  20.041667
# 375219  Pennsylvania   York  2014-12-31  Parts per billion  12.875000
# 375220  Pennsylvania   York  2014-12-31  Parts per billion  12.875000
# 375221  Pennsylvania   York  2014-12-31  Parts per billion  12.875000
# 375222  Pennsylvania   York  2014-12-31  Parts per billion  12.875000
#
#         NO2 1st Max Value  NO2 1st Max Hour  NO2 AQI           O3 Units  \
# ...

# %%
save
# Out:
#           State    County  Date Local          NO2 Units   NO2 Mean  \
# 0       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 1       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 2       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 3       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 4       Arizona  Maricopa  2012-01-02  Parts per billion  17.208333
# ...         ...       ...         ...                ...        ...
# 394366  Wyoming   Laramie  2014-12-30  Parts per billion   7.579167
# 394367  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
# 394368  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
# 394369  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
# 394370  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
#
#         NO2 1st Max Value  NO2 1st Max Hour  NO2 AQI           O3 Units  \
# 0                    33.0                 0       31  Parts per million
# ...

# %%
save.loc[save['SO2 AQI'] == '161']
# Out:
# /home/peter/anaconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# Empty DataFrame
# Columns: [State, County, Date Local, NO2 Units, NO2 Mean, NO2 1st Max Value, NO2 1st Max Hour, NO2 AQI, O3 Units, O3 Mean, O3 1st Max Value, O3 1st Max Hour, O3 AQI, SO2 Units, SO2 Mean, SO2 1st Max Value, SO2 1st Max Hour, SO2 AQI, CO Units, CO Mean, CO 1st Max Value, CO 1st Max Hour, CO AQI]
# Index: []
#
# [0 rows x 23 columns]

# %%
save
# Out:
#           State    County  Date Local          NO2 Units   NO2 Mean  \
# 0       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 1       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 2       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 3       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 4       Arizona  Maricopa  2012-01-02  Parts per billion  17.208333
# ...         ...       ...         ...                ...        ...
# 394366  Wyoming   Laramie  2014-12-30  Parts per billion   7.579167
# 394367  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
# 394368  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
# 394369  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
# 394370  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
#
#         NO2 1st Max Value  NO2 1st Max Hour  NO2 AQI           O3 Units  \
# 0                    33.0                 0       31  Parts per million
# ...

# %%
save.loc[save['SO2 AQI'] == '161.0']
# Out:
# /home/peter/anaconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# Empty DataFrame
# Columns: [State, County, Date Local, NO2 Units, NO2 Mean, NO2 1st Max Value, NO2 1st Max Hour, NO2 AQI, O3 Units, O3 Mean, O3 1st Max Value, O3 1st Max Hour, O3 AQI, SO2 Units, SO2 Mean, SO2 1st Max Value, SO2 1st Max Hour, SO2 AQI, CO Units, CO Mean, CO 1st Max Value, CO 1st Max Hour, CO AQI]
# Index: []
#
# [0 rows x 23 columns]

# %%
save.loc[save['SO2 AQI'] == 161.0]
# Out:
#          State  County  Date Local          NO2 Units   NO2 Mean  \
# 64016  Indiana  Marion  2012-06-09  Parts per billion  22.866667
# 64017  Indiana  Marion  2012-06-09  Parts per billion  22.866667
#
#        NO2 1st Max Value  NO2 1st Max Hour  NO2 AQI           O3 Units  \
# 64016               26.8                 0       25  Parts per million
# 64017               26.8                 0       25  Parts per million
#
#         O3 Mean  ...          SO2 Units   SO2 Mean  SO2 1st Max Value  \
# 64016  0.048125  ...  Parts per billion  13.404348              211.9
# 64017  0.048125  ...  Parts per billion  13.404348              211.9
#
#       SO2 1st Max Hour  SO2 AQI           CO Units   CO Mean  \
# 64016                8    161.0  Parts per million  0.483333
# 64017                8    161.0  Parts per million  0.491667
#
#        CO 1st Max Value CO 1st Max Hour  CO AQI
# 64016               0.7               0     NaN
# 64017               0.6               1     7.0
#
# ...

# %%
test
# Out:
#           State    County  Date Local          NO2 Units   NO2 Mean  \
# 0       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 1       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 2       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 3       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 4       Arizona  Maricopa  2012-01-02  Parts per billion  17.208333
# ...         ...       ...         ...                ...        ...
# 394366  Wyoming   Laramie  2014-12-30  Parts per billion   7.579167
# 394367  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
# 394368  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
# 394369  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
# 394370  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
#
#         NO2 1st Max Value  NO2 1st Max Hour  NO2 AQI           O3 Units  \
# 0                    33.0                 0       31  Parts per million
# ...

# %%
test.isna().sum()
# Out:
# State                     0
# County                    0
# Date Local                0
# NO2 Units                 0
# NO2 Mean                  0
# NO2 1st Max Value         0
# NO2 1st Max Hour          0
# NO2 AQI                   0
# O3 Units                  0
# O3 Mean                   0
# O3 1st Max Value          0
# O3 1st Max Hour           0
# O3 AQI                    0
# SO2 Units                 0
# SO2 Mean                  0
# SO2 1st Max Value         0
# SO2 1st Max Hour          0
# SO2 AQI              197057
# CO Units                  0
# CO Mean                   0
# CO 1st Max Value          0
# CO 1st Max Hour           0
# CO AQI               197210
# dtype: int64

# %%
test['SO2 AQI'].mean()
# Out:
# 3.110047943886394

# %%
test['CO AQI'].mean()
# Out:
# 4.374440178331414

# %%
test['NO2 AQI'].mean()
# Out:
# 19.900045895869624

# %%
test1=test

# %%
test1
# Out:
#           State    County  Date Local          NO2 Units   NO2 Mean  \
# 0       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 1       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 2       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 3       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 4       Arizona  Maricopa  2012-01-02  Parts per billion  17.208333
# ...         ...       ...         ...                ...        ...
# 394366  Wyoming   Laramie  2014-12-30  Parts per billion   7.579167
# 394367  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
# 394368  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
# 394369  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
# 394370  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
#
#         NO2 1st Max Value  NO2 1st Max Hour  NO2 AQI           O3 Units  \
# 0                    33.0                 0       31  Parts per million
# ...

# %%
test1['SO2 AQI'] = test1['SO2 AQI'].fillna(3.1)

# %%
test1
# Out:
#           State    County  Date Local          NO2 Units   NO2 Mean  \
# 0       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 1       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 2       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 3       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 4       Arizona  Maricopa  2012-01-02  Parts per billion  17.208333
# ...         ...       ...         ...                ...        ...
# 394366  Wyoming   Laramie  2014-12-30  Parts per billion   7.579167
# 394367  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
# 394368  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
# 394369  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
# 394370  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
#
#         NO2 1st Max Value  NO2 1st Max Hour  NO2 AQI           O3 Units  \
# 0                    33.0                 0       31  Parts per million
# ...

# %%
test1['SO2 AQI'].mean()
# Out:
# 3.1050272459172916

# %%
test1['CO AQI'] = test1['CO AQI'].fillna(4.3)

# %%
test1
# Out:
#           State    County  Date Local          NO2 Units   NO2 Mean  \
# 0       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 1       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 2       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 3       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 4       Arizona  Maricopa  2012-01-02  Parts per billion  17.208333
# ...         ...       ...         ...                ...        ...
# 394366  Wyoming   Laramie  2014-12-30  Parts per billion   7.579167
# 394367  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
# 394368  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
# 394369  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
# 394370  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
#
#         NO2 1st Max Value  NO2 1st Max Hour  NO2 AQI           O3 Units  \
# 0                    33.0                 0       31  Parts per million
# ...

# %%
test1['CO AQI'].mean()
# Out:
# 4.337215464641085

# %%
test['NO2 AQI'].mean()
# Out:
# 19.900045895869624

# %%
test1.isna().sum()
# Out:
# State                0
# County               0
# Date Local           0
# NO2 Units            0
# NO2 Mean             0
# NO2 1st Max Value    0
# NO2 1st Max Hour     0
# NO2 AQI              0
# O3 Units             0
# O3 Mean              0
# O3 1st Max Value     0
# O3 1st Max Hour      0
# O3 AQI               0
# SO2 Units            0
# SO2 Mean             0
# SO2 1st Max Value    0
# SO2 1st Max Hour     0
# SO2 AQI              0
# CO Units             0
# CO Mean              0
# CO 1st Max Value     0
# CO 1st Max Hour      0
# CO AQI               0
# dtype: int64

# %%
test1
# Out:
#           State    County  Date Local          NO2 Units   NO2 Mean  \
# 0       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 1       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 2       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 3       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 4       Arizona  Maricopa  2012-01-02  Parts per billion  17.208333
# ...         ...       ...         ...                ...        ...
# 394366  Wyoming   Laramie  2014-12-30  Parts per billion   7.579167
# 394367  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
# 394368  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
# 394369  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
# 394370  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
#
#         NO2 1st Max Value  NO2 1st Max Hour  NO2 AQI           O3 Units  \
# 0                    33.0                 0       31  Parts per million
# ...

# %%
test1.to_csv(r'/home/peter/Documents/DSProject/FilteredDataFour.csv', index=False)
