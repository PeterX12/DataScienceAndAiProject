# %%
import pandas as pd

# %%
linear = pd.read_csv('/home/peter/Documents/DSProject/FilteredDataTwo.csv')

# %%
linear
# Out:
#           State    County           City  Date Local          NO2 Units  \
# 0       Arizona  Maricopa        Phoenix  2012-01-01  Parts per billion
# 1       Arizona  Maricopa        Phoenix  2012-01-01  Parts per billion
# 2       Arizona  Maricopa        Phoenix  2012-01-01  Parts per billion
# 3       Arizona  Maricopa        Phoenix  2012-01-01  Parts per billion
# 4       Arizona  Maricopa        Phoenix  2012-01-02  Parts per billion
# ...         ...       ...            ...         ...                ...
# 394366  Wyoming   Laramie  Not in a city  2014-12-30  Parts per billion
# 394367  Wyoming   Laramie  Not in a city  2014-12-31  Parts per billion
# 394368  Wyoming   Laramie  Not in a city  2014-12-31  Parts per billion
# 394369  Wyoming   Laramie  Not in a city  2014-12-31  Parts per billion
# 394370  Wyoming   Laramie  Not in a city  2014-12-31  Parts per billion
#
#          NO2 Mean  NO2 1st Max Value  NO2 1st Max Hour  NO2 AQI  \
# ...

# %%
startdate = "2012-01-01"
enddate = "2012-12-31"
afterStartDate = linear["Date Local"] >= startdate
beforeEndDate = linear["Date Local"] <= enddate
between = afterStartDate & beforeEndDate
filtered = linear.loc[between]

# %%
filtered
# Out:
#           State      County  Date Local          NO2 Units   NO2 Mean  \
# 0       Arizona    Maricopa  2012-01-01  Parts per billion  21.208333
# 1       Arizona    Maricopa  2012-01-01  Parts per billion  21.208333
# 2       Arizona    Maricopa  2012-01-01  Parts per billion  21.208333
# 3       Arizona    Maricopa  2012-01-01  Parts per billion  21.208333
# 4       Arizona    Maricopa  2012-01-02  Parts per billion  17.208333
# ...         ...         ...         ...                ...        ...
# 128201  Wyoming  Sweetwater  2012-12-30  Parts per billion  21.166667
# 128202  Wyoming  Sweetwater  2012-12-31  Parts per billion  19.565217
# 128203  Wyoming  Sweetwater  2012-12-31  Parts per billion  19.565217
# 128204  Wyoming  Sweetwater  2012-12-31  Parts per billion  19.565217
# 128205  Wyoming  Sweetwater  2012-12-31  Parts per billion  19.565217
#
#         NO2 1st Max Value  NO2 1st Max Hour  NO2 AQI           O3 Units  \
# ...

# %%
filtered.to_csv(r'/home/peter/Documents/DSProject/2012Data.csv', index=False)

# %%
linear
# Out:
#           State    County  Date Local          NO2 Units   NO2 Mean  \
# 0       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 1       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 2       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 3       Arizona  Maricopa  2012-01-01  Parts per billion  21.208333
# 4       Arizona  Maricopa  2012-01-02  Parts per billion  17.208333
# ...         ...       ...         ...                ...        ...
# 394366  Wyoming   Laramie  2014-12-30  Parts per billion   7.579167
# 394367  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
# 394368  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
# 394369  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
# 394370  Wyoming   Laramie  2014-12-31  Parts per billion   4.420833
#
#         NO2 1st Max Value  NO2 1st Max Hour  NO2 AQI           O3 Units  \
# 0                    33.0                 0       31  Parts per million
# ...

# %%
startdate = "2013-01-01"
enddate = "2013-12-31"
afterStartDate = linear["Date Local"] >= startdate
beforeEndDate = linear["Date Local"] <= enddate
between = afterStartDate & beforeEndDate
filtered2 = linear.loc[between]

# %%
filtered2
# Out:
#           State     County  Date Local          NO2 Units   NO2 Mean  \
# 128206  Alabama  Jefferson  2013-12-01  Parts per billion  17.208333
# 128207  Alabama  Jefferson  2013-12-01  Parts per billion  17.208333
# 128208  Alabama  Jefferson  2013-12-01  Parts per billion  17.208333
# 128209  Alabama  Jefferson  2013-12-01  Parts per billion  17.208333
# 128210  Alabama  Jefferson  2013-12-02  Parts per billion  20.687500
# ...         ...        ...         ...                ...        ...
# 262777  Wyoming    Laramie  2013-12-30  Parts per billion   3.426087
# 262778  Wyoming    Laramie  2013-12-31  Parts per billion   1.004167
# 262779  Wyoming    Laramie  2013-12-31  Parts per billion   1.004167
# 262780  Wyoming    Laramie  2013-12-31  Parts per billion   1.004167
# 262781  Wyoming    Laramie  2013-12-31  Parts per billion   1.004167
#
#         NO2 1st Max Value  NO2 1st Max Hour  NO2 AQI           O3 Units  \
# ...

# %%
filtered2.to_csv(r'/home/peter/Documents/DSProject/2013Data.csv', index=False)

# %%
filtered2
# Out:
#           State     County  Date Local          NO2 Units   NO2 Mean  \
# 128206  Alabama  Jefferson  2013-12-01  Parts per billion  17.208333
# 128207  Alabama  Jefferson  2013-12-01  Parts per billion  17.208333
# 128208  Alabama  Jefferson  2013-12-01  Parts per billion  17.208333
# 128209  Alabama  Jefferson  2013-12-01  Parts per billion  17.208333
# 128210  Alabama  Jefferson  2013-12-02  Parts per billion  20.687500
# ...         ...        ...         ...                ...        ...
# 262777  Wyoming    Laramie  2013-12-30  Parts per billion   3.426087
# 262778  Wyoming    Laramie  2013-12-31  Parts per billion   1.004167
# 262779  Wyoming    Laramie  2013-12-31  Parts per billion   1.004167
# 262780  Wyoming    Laramie  2013-12-31  Parts per billion   1.004167
# 262781  Wyoming    Laramie  2013-12-31  Parts per billion   1.004167
#
#         NO2 1st Max Value  NO2 1st Max Hour  NO2 AQI           O3 Units  \
# ...

# %%
startdate = "2014-01-01"
enddate = "2014-12-31"
afterStartDate = linear["Date Local"] >= startdate
beforeEndDate = linear["Date Local"] <= enddate
between = afterStartDate & beforeEndDate
filtered3 = linear.loc[between]

# %%
filtered3
# Out:
#           State     County  Date Local          NO2 Units   NO2 Mean  \
# 262782  Alabama  Jefferson  2014-01-01  Parts per billion  16.512500
# 262783  Alabama  Jefferson  2014-01-01  Parts per billion  16.512500
# 262784  Alabama  Jefferson  2014-01-01  Parts per billion  16.512500
# 262785  Alabama  Jefferson  2014-01-01  Parts per billion  16.512500
# 262786  Alabama  Jefferson  2014-01-02  Parts per billion   3.662500
# ...         ...        ...         ...                ...        ...
# 394366  Wyoming    Laramie  2014-12-30  Parts per billion   7.579167
# 394367  Wyoming    Laramie  2014-12-31  Parts per billion   4.420833
# 394368  Wyoming    Laramie  2014-12-31  Parts per billion   4.420833
# 394369  Wyoming    Laramie  2014-12-31  Parts per billion   4.420833
# 394370  Wyoming    Laramie  2014-12-31  Parts per billion   4.420833
#
#         NO2 1st Max Value  NO2 1st Max Hour  NO2 AQI           O3 Units  \
# ...

# %%
filtered3.to_csv(r'/home/peter/Documents/DSProject/2014Data.csv', index=False)
