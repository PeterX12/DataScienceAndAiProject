# %%
import pandas as pd

# %%
test = pd.read_csv('/home/peter/Documents/DSProject/Data.csv')

# %%
test
# Out:
#          Unnamed: 0  State Code  County Code  Site Num  \
# 0                 0           4           13      3002
# 1                 1           4           13      3002
# 2                 2           4           13      3002
# 3                 3           4           13      3002
# 4                 4           4           13      3002
# ...             ...         ...          ...       ...
# 1746656       24599          56           21       100
# 1746657       24600          56           21       100
# 1746658       24601          56           21       100
# 1746659       24602          56           21       100
# 1746660       24603          56           21       100
#
#                                          Address    State    County  \
# 0        1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa
# 1        1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa
# 2        1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa
# ...

# %%
test.drop('Address', inplace=True, axis=1)

# %%
test
# Out:
#          Unnamed: 0  State Code  County Code  Site Num    State    County  \
# 0                 0           4           13      3002  Arizona  Maricopa
# 1                 1           4           13      3002  Arizona  Maricopa
# 2                 2           4           13      3002  Arizona  Maricopa
# 3                 3           4           13      3002  Arizona  Maricopa
# 4                 4           4           13      3002  Arizona  Maricopa
# ...             ...         ...          ...       ...      ...       ...
# 1746656       24599          56           21       100  Wyoming   Laramie
# 1746657       24600          56           21       100  Wyoming   Laramie
# 1746658       24601          56           21       100  Wyoming   Laramie
# 1746659       24602          56           21       100  Wyoming   Laramie
# 1746660       24603          56           21       100  Wyoming   Laramie
#
#                   City  Date Local          NO2 Units   NO2 Mean  ...  \
# ...

# %%
test.drop('Unnamed: 0', inplace=True, axis=1)

# %%
test
# Out:
#          State Code  County Code  Site Num    State    County           City  \
# 0                 4           13      3002  Arizona  Maricopa        Phoenix
# 1                 4           13      3002  Arizona  Maricopa        Phoenix
# 2                 4           13      3002  Arizona  Maricopa        Phoenix
# 3                 4           13      3002  Arizona  Maricopa        Phoenix
# 4                 4           13      3002  Arizona  Maricopa        Phoenix
# ...             ...          ...       ...      ...       ...            ...
# 1746656          56           21       100  Wyoming   Laramie  Not in a city
# 1746657          56           21       100  Wyoming   Laramie  Not in a city
# 1746658          56           21       100  Wyoming   Laramie  Not in a city
# 1746659          56           21       100  Wyoming   Laramie  Not in a city
# 1746660          56           21       100  Wyoming   Laramie  Not in a city
#
# ...

# %%
test.drop('State Code', inplace=True, axis=1)

# %%
test
# Out:
#          County Code  Site Num    State    County           City  Date Local  \
# 0                 13      3002  Arizona  Maricopa        Phoenix  2000-01-01
# 1                 13      3002  Arizona  Maricopa        Phoenix  2000-01-01
# 2                 13      3002  Arizona  Maricopa        Phoenix  2000-01-01
# 3                 13      3002  Arizona  Maricopa        Phoenix  2000-01-01
# 4                 13      3002  Arizona  Maricopa        Phoenix  2000-01-02
# ...              ...       ...      ...       ...            ...         ...
# 1746656           21       100  Wyoming   Laramie  Not in a city  2016-03-30
# 1746657           21       100  Wyoming   Laramie  Not in a city  2016-03-31
# 1746658           21       100  Wyoming   Laramie  Not in a city  2016-03-31
# 1746659           21       100  Wyoming   Laramie  Not in a city  2016-03-31
# 1746660           21       100  Wyoming   Laramie  Not in a city  2016-03-31
#
# ...

# %%
test.drop('County Code', inplace=True, axis=1)

# %%
test
# Out:
#          Site Num    State    County           City  Date Local  \
# 0            3002  Arizona  Maricopa        Phoenix  2000-01-01
# 1            3002  Arizona  Maricopa        Phoenix  2000-01-01
# 2            3002  Arizona  Maricopa        Phoenix  2000-01-01
# 3            3002  Arizona  Maricopa        Phoenix  2000-01-01
# 4            3002  Arizona  Maricopa        Phoenix  2000-01-02
# ...           ...      ...       ...            ...         ...
# 1746656       100  Wyoming   Laramie  Not in a city  2016-03-30
# 1746657       100  Wyoming   Laramie  Not in a city  2016-03-31
# 1746658       100  Wyoming   Laramie  Not in a city  2016-03-31
# 1746659       100  Wyoming   Laramie  Not in a city  2016-03-31
# 1746660       100  Wyoming   Laramie  Not in a city  2016-03-31
#
#                  NO2 Units   NO2 Mean  NO2 1st Max Value  NO2 1st Max Hour  \
# 0        Parts per billion  19.041667               49.0                19
# ...

# %%
test.drop('Site Num', inplace=True, axis=1)

# %%
test
# Out:
#            State    County           City  Date Local          NO2 Units  \
# 0        Arizona  Maricopa        Phoenix  2000-01-01  Parts per billion
# 1        Arizona  Maricopa        Phoenix  2000-01-01  Parts per billion
# 2        Arizona  Maricopa        Phoenix  2000-01-01  Parts per billion
# 3        Arizona  Maricopa        Phoenix  2000-01-01  Parts per billion
# 4        Arizona  Maricopa        Phoenix  2000-01-02  Parts per billion
# ...          ...       ...            ...         ...                ...
# 1746656  Wyoming   Laramie  Not in a city  2016-03-30  Parts per billion
# 1746657  Wyoming   Laramie  Not in a city  2016-03-31  Parts per billion
# 1746658  Wyoming   Laramie  Not in a city  2016-03-31  Parts per billion
# 1746659  Wyoming   Laramie  Not in a city  2016-03-31  Parts per billion
# 1746660  Wyoming   Laramie  Not in a city  2016-03-31  Parts per billion
#
#           NO2 Mean  NO2 1st Max Value  NO2 1st Max Hour  NO2 AQI  \
# ...

# %%
filteredOne = test

# %%
startDate="2012-01-01"
endDate="2014-12-31"
afterStartDate=test["Date Local"] >= startDate
beforeEndDate=test["Date Local"] <= endDate
betweenDate=afterStartDate & beforeEndDate

# %%
filterDate = test.loc[betweenDate]

# %%
filterDate
# Out:
#            State    County           City  Date Local          NO2 Units  \
# 1201630  Arizona  Maricopa        Phoenix  2012-01-01  Parts per billion
# 1201631  Arizona  Maricopa        Phoenix  2012-01-01  Parts per billion
# 1201632  Arizona  Maricopa        Phoenix  2012-01-01  Parts per billion
# 1201633  Arizona  Maricopa        Phoenix  2012-01-01  Parts per billion
# 1201634  Arizona  Maricopa        Phoenix  2012-01-02  Parts per billion
# ...          ...       ...            ...         ...                ...
# 1595996  Wyoming   Laramie  Not in a city  2014-12-30  Parts per billion
# 1595997  Wyoming   Laramie  Not in a city  2014-12-31  Parts per billion
# 1595998  Wyoming   Laramie  Not in a city  2014-12-31  Parts per billion
# 1595999  Wyoming   Laramie  Not in a city  2014-12-31  Parts per billion
# 1596000  Wyoming   Laramie  Not in a city  2014-12-31  Parts per billion
#
#           NO2 Mean  NO2 1st Max Value  NO2 1st Max Hour  NO2 AQI  \
# ...

# %%
filteredTwo=filterDate

# %%
filteredTwo
# Out:
#            State    County           City  Date Local          NO2 Units  \
# 1201630  Arizona  Maricopa        Phoenix  2012-01-01  Parts per billion
# 1201631  Arizona  Maricopa        Phoenix  2012-01-01  Parts per billion
# 1201632  Arizona  Maricopa        Phoenix  2012-01-01  Parts per billion
# 1201633  Arizona  Maricopa        Phoenix  2012-01-01  Parts per billion
# 1201634  Arizona  Maricopa        Phoenix  2012-01-02  Parts per billion
# ...          ...       ...            ...         ...                ...
# 1595996  Wyoming   Laramie  Not in a city  2014-12-30  Parts per billion
# 1595997  Wyoming   Laramie  Not in a city  2014-12-31  Parts per billion
# 1595998  Wyoming   Laramie  Not in a city  2014-12-31  Parts per billion
# 1595999  Wyoming   Laramie  Not in a city  2014-12-31  Parts per billion
# 1596000  Wyoming   Laramie  Not in a city  2014-12-31  Parts per billion
#
#           NO2 Mean  NO2 1st Max Value  NO2 1st Max Hour  NO2 AQI  \
# ...

# %%
filteredTwo.to_csv(r'/home/peter/Documents/DSProject/FilteredDataTwo.csv', index=False)

# %%
testTwo = pd.read_csv('/home/peter/Documents/DSProject/FilteredData.csv')

# %%
testTwo
# Out:
#         Unnamed: 0    State    County           City  Date Local  \
# 0          1201630  Arizona  Maricopa        Phoenix  2012-01-01
# 1          1201631  Arizona  Maricopa        Phoenix  2012-01-01
# 2          1201632  Arizona  Maricopa        Phoenix  2012-01-01
# 3          1201633  Arizona  Maricopa        Phoenix  2012-01-01
# 4          1201634  Arizona  Maricopa        Phoenix  2012-01-02
# ...            ...      ...       ...            ...         ...
# 394366     1595996  Wyoming   Laramie  Not in a city  2014-12-30
# 394367     1595997  Wyoming   Laramie  Not in a city  2014-12-31
# 394368     1595998  Wyoming   Laramie  Not in a city  2014-12-31
# 394369     1595999  Wyoming   Laramie  Not in a city  2014-12-31
# 394370     1596000  Wyoming   Laramie  Not in a city  2014-12-31
#
#                 NO2 Units   NO2 Mean  NO2 1st Max Value  NO2 1st Max Hour  \
# 0       Parts per billion  21.208333               33.0                 0
# ...

# %%
test3 = pd.read_csv('/home/peter/Documents/DSProject/FilteredDataTwo.csv')

# %%
test3
# Out:
#           State    County           City  Date Local          NO2 Units  \
# 0       Arizona  Maricopa        Phoenix  2012-01-01  Parts per billion
# 1       Arizona  Maricopa        Phoenix  2012-01-01  Parts per billion
# 2       Arizona  Maricopa        Phoenix  2012-01-01  Parts per billion
# 3       Arizona  Maricopa        Phoenix  2012-01-01  Parts per billion
# 4       Arizona  Maricopa        Phoenix  2012-01-02  Parts per billion
# ...         ...       ...            ...         ...                ...
# 394366  Wyoming   Laramie  Not in a city  2014-12-30  Parts per billion
# 394367  Wyoming   Laramie  Not in a city  2014-12-31  Parts per billion
# 394368  Wyoming   Laramie  Not in a city  2014-12-31  Parts per billion
# 394369  Wyoming   Laramie  Not in a city  2014-12-31  Parts per billion
# 394370  Wyoming   Laramie  Not in a city  2014-12-31  Parts per billion
#
#          NO2 Mean  NO2 1st Max Value  NO2 1st Max Hour  NO2 AQI  \
# ...

# %%
test.drop('County', inplace=True, axis=1)

# %%
test.drop('City', inplace=True, axis=1)

# %%
test3.drop('State Code', inplace=True, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-0fa53accf7a2> in <module>
# ----> 1 test3.drop('State Code', inplace=True, axis=1)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
test3

# %%
test3.drop('City', inplace=True, axis=1)

# %%
test3

# %%
test3 = pd.read_csv('/home/peter/Documents/DSProject/FilteredDataThree.csv')

# %%
test3.to_csv(r'/home/peter/Documents/DSProject/FilteredDataThree.csv', index=False)

# %%
test4 = pd.read_csv('/home/peter/Documents/DSProject/FilteredDataThree.csv')

# %%
test4

# %%
test4.loc[iddex=State]

# %%
test4 = test4.drop_duplicates()

# %%
test5 = test4

# %%
test5.dropna(inplace=True)

# %%
test5

# %%
test5.dropna(inplace=True)

# %%
test.head()

# %%
test.info()

# %%
test5.isnull()

# %%
test5.info()

# %%
test5.dropna(inplace=True)

# %%
test5

# %%
test4

# %%
test5

# %%
test3

# %%
test6 = test3

# %%
test6

# %%
test6.isNull()

# %%
test6.isnull()

# %%
NullTest=test6

# %%
NullTest.drop('NO2 AQI', inplace=True, axis=1)

# %%
NullTest

# %%
NullTest.dropna(inplace=True)

# %%
NullTest

# %%
test3

# %%
test6

# %%
test4

# %%
test6

# %%
test6

# %%
test2

# %%
final = pd.read_csv('/home/peter/Documents/DSProject/FilteredDataTwo.csv')

# %%
final

# %%
test3 = pd.read_csv('/home/peter/Documents/DSProject/FilteredDataThree.csv')

# %%
test3

# %%
test3

# %%
test
# Out:
#            State  Date Local          NO2 Units   NO2 Mean  NO2 1st Max Value  \
# 0        Arizona  2000-01-01  Parts per billion  19.041667               49.0
# 1        Arizona  2000-01-01  Parts per billion  19.041667               49.0
# 2        Arizona  2000-01-01  Parts per billion  19.041667               49.0
# 3        Arizona  2000-01-01  Parts per billion  19.041667               49.0
# 4        Arizona  2000-01-02  Parts per billion  22.958333               36.0
# ...          ...         ...                ...        ...                ...
# 1746656  Wyoming  2016-03-30  Parts per billion   1.083333                1.6
# 1746657  Wyoming  2016-03-31  Parts per billion   0.939130                1.3
# 1746658  Wyoming  2016-03-31  Parts per billion   0.939130                1.3
# 1746659  Wyoming  2016-03-31  Parts per billion   0.939130                1.3
# 1746660  Wyoming  2016-03-31  Parts per billion   0.939130                1.3
#
# ...
